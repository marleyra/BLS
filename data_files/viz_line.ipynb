# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import textwrap

# for custom system fonts
import os
from matplotlib import font_manager as fm

# %%
# grab system font
fpath = os.path.join('/Users/marley/Library/Fonts/CENSCBK.TTF')
prop = fm.FontProperties(fname=fpath, size=10)
fname = os.path.split(fpath)[1]

# %%
files = ['ch2_fig18.csv', 'ch2_fig19.csv']
file = files[0]
g = pd.read_csv(file)
g = g.set_index(g.iloc[:,0])
g = g.drop(g.iloc[:,0].name, axis=1)
g
# Out:
#                                                     Coastal West  \
# Urban/Rural County Pop Share with at least a BA...
# 1990                                                       0.189
# 2000                                                       0.225
# 2010                                                       0.244
# 2019                                                       0.298
#
#                                                     Interior Northwest  \
# Urban/Rural County Pop Share with at least a BA...
# 1990                                                             0.158
# 2000                                                             0.190
# 2010                                                             0.216
# 2019                                                             0.249
#
#                                                     Mid-Atlantic  Midwest  \
# Urban/Rural County Pop Share with at least a BA...
# 1990                                                       0.163    0.138
# 2000                                                       0.205    0.179
# 2010                                                       0.238    0.217
# 2019                                                       0.288    0.250
#
#                                                     New England  South  \
# Urban/Rural County Pop Share with at least a BA...
# 1990                                                      0.242  0.120
# 2000                                                      0.291  0.154
# 2010                                                      0.329  0.179
# 2019                                                      0.381  0.212
#
#                                                     Southwest  Total  \
# Urban/Rural County Pop Share with at least a BA...
# 1990                                                    0.198  0.143
# 2000                                                    0.237  0.180
# 2010                                                    0.277  0.213
# 2019                                                    0.311  0.245
#
#                                                     Coastal West.1  \
# Urban/Rural County Pop Share with at least a BA...
# 1990                                                         0.139
# 2000                                                         0.165
# 2010                                                         0.189
# 2019                                                         0.198
#
#                                                     Interior Northwest.1  \
# Urban/Rural County Pop Share with at least a BA...
# 1990                                                               0.134
# 2000                                                               0.165
# 2010                                                               0.174
# 2019                                                               0.214
#
#                                                     Mid-Atlantic.1  Midwest.1  \
# Urban/Rural County Pop Share with at least a BA...
# 1990                                                         0.112      0.107
# 2000                                                         0.133      0.136
# 2010                                                         0.154      0.159
# 2019                                                         0.187      0.188
#
#                                                     New England.1  South.1  \
# Urban/Rural County Pop Share with at least a BA...
# 1990                                                        0.184    0.090
# 2000                                                        0.224    0.106
# 2010                                                        0.257    0.122
# 2019                                                        0.302    0.141
#
#                                                     Southwest.1  Total.1
# Urban/Rural County Pop Share with at least a BA...
# 1990                                                      0.130    0.105
# 2000                                                      0.155    0.128
# 2010                                                      0.186    0.150
# 2019                                                      0.208    0.173

# %%
u = g.iloc[:,0:8]
r = g.iloc[:,8:]
r.columns = u.columns

# %%
# set graph specs
legendheight = -0.2
title = 'Median County Educational Attainment'#g.index.name#[:-11]

# define text wrapping function
def wrap_labels(ax, width, break_long_words=False):
    labels = []
    for label in ax.get_xticklabels():
        text = label.get_text()
        labels.append(textwrap.fill(text, width=width,
                                    break_long_words=break_long_words))
    ax.set_xticklabels(labels, rotation=0) 
    
fig, ax = plt.subplots(figsize=(9,5))
ax.grid(visible=None, which='major', axis='y', linestyle = ':', linewidth = .75, zorder=0)
    
line1 = ax.plot(u.iloc[:,-1], zorder=3, color='black', lw=1, label='Urban')
line1 = ax.plot(r.iloc[:,-1], zorder=3, color='black', lw=1, ls='--', label='Rural')
#bar2 = ax.bar(x_rural, g.Rural, width, zorder=3, label='Rural', color='white', edgecolor='black', hatch='/////////', lw=.7)
ax.bar(g.index, 0)
   
ax.set_title(title, fontproperties=prop, size=12)
#ax.set_ylabel(ytitle, fontproperties=prop) # set title and font
ax.tick_params(axis='both', left=False, bottom=True) # remove Y axis ticks
ax.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1, decimals=0)) # turn y axis decimals into %s

for label in ax.get_yticklabels():
    label.set_fontproperties(prop)
    label.set_fontsize(8) 
    
for label in ax.get_xticklabels():
    label.set_fontproperties(prop)
    label.set_fontsize(9)   

ax.legend(prop=prop, loc='lower center', bbox_to_anchor=(0.5, legendheight), frameon=False, ncol=2)
    
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)

plt.xticks(ticks=[1990, 2000, 2010, 2019], labels=['1990', '2000', '2010', '2019'])

ax.set(ylim=(0, .33), xlim=(1989,2020))
#ax.set(ylim=(0, 1))
#ax.set(ylim=(-.5,.5))
plt.show()

# %%
# if good, export
ax.get_figure().savefig(file[:-4] + '.jpg', dpi=300, bbox_inches='tight')

# %%
file = files[1]
g = pd.read_csv(file)
g = g.set_index(g.iloc[:,0])
g = g.drop(g.iloc[:,0].name, axis=1)
g
# Out:
#                                               Coastal West  \
# Income Inequality by Urban/Rural (1990–2019)
# 1990                                                 0.149
# 2000                                                 0.128
# 2010                                                 0.134
# 2019                                                 0.182
#
#                                               Interior Northwest  \
# Income Inequality by Urban/Rural (1990–2019)
# 1990                                                       0.178
# 2000                                                       0.116
# 2010                                                       0.108
# 2019                                                       0.127
#
#                                               Mid-Atlantic  Midwest  \
# Income Inequality by Urban/Rural (1990–2019)
# 1990                                                 0.148    0.156
# 2000                                                 0.119    0.103
# 2010                                                 0.137    0.112
# 2019                                                 0.178    0.145
#
#                                               New England  South  Southwest  \
# Income Inequality by Urban/Rural (1990–2019)
# 1990                                                0.131  0.205      0.141
# 2000                                                0.121  0.139      0.111
# 2010                                                0.156  0.134      0.126
# 2019                                                0.217  0.156      0.168
#
#                                               Total  Coastal West.1  \
# Income Inequality by Urban/Rural (1990–2019)
# 1990                                          0.170           0.192
# 2000                                          0.124           0.134
# 2010                                          0.129           0.114
# 2019                                          0.158           0.137
#
#                                               Interior Northwest.1  \
# Income Inequality by Urban/Rural (1990–2019)
# 1990                                                         0.211
# 2000                                                         0.140
# 2010                                                         0.116
# 2019                                                         0.122
#
#                                               Mid-Atlantic.1  Midwest.1  \
# Income Inequality by Urban/Rural (1990–2019)
# 1990                                                   0.217      0.219
# 2000                                                   0.145      0.123
# 2010                                                   0.126      0.105
# 2019                                                   0.132      0.119
#
#                                               New England.1  South.1  \
# Income Inequality by Urban/Rural (1990–2019)
# 1990                                                  0.177    0.289
# 2000                                                  0.125    0.186
# 2010                                                  0.118    0.147
# 2019                                                  0.132    0.143
#
#                                               Southwest.1  Total.1
# Income Inequality by Urban/Rural (1990–2019)
# 1990                                                0.216    0.238
# 2000                                                0.140    0.146
# 2010                                                0.118    0.120
# 2019                                                0.124    0.129

# %%
u = g.iloc[:,0:8]
r = g.iloc[:,8:]
r.columns = u.columns

# %%
# set graph specs
legendheight = -0.2
title = 'Median County Income Inequality'#g.index.name#[:-11]

# define text wrapping function
def wrap_labels(ax, width, break_long_words=False):
    labels = []
    for label in ax.get_xticklabels():
        text = label.get_text()
        labels.append(textwrap.fill(text, width=width,
                                    break_long_words=break_long_words))
    ax.set_xticklabels(labels, rotation=0) 
    
fig, ax = plt.subplots(figsize=(9,5))
ax.grid(visible=None, which='major', axis='y', linestyle = ':', linewidth = .75, zorder=0)
    
line1 = ax.plot(u.iloc[:,-1], zorder=3, color='black', lw=1, label='Urban')
line1 = ax.plot(r.iloc[:,-1], zorder=3, color='black', lw=1, ls='--', label='Rural')
#bar2 = ax.bar(x_rural, g.Rural, width, zorder=3, label='Rural', color='white', edgecolor='black', hatch='/////////', lw=.7)
ax.bar(g.index, 0)
   
ax.set_title(title, fontproperties=prop, size=12)
#ax.set_ylabel(ytitle, fontproperties=prop) # set title and font
ax.tick_params(axis='both', left=False, bottom=True) # remove Y axis ticks
ax.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1, decimals=0)) # turn y axis decimals into %s

for label in ax.get_yticklabels():
    label.set_fontproperties(prop)
    label.set_fontsize(8) 
    
for label in ax.get_xticklabels():
    label.set_fontproperties(prop)
    label.set_fontsize(9)   

ax.legend(prop=prop, loc='lower center', bbox_to_anchor=(0.5, legendheight), frameon=False, ncol=2)
    
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)

plt.xticks(ticks=[1990, 2000, 2010, 2019], labels=['1990', '2000', '2010', '2019'])

ax.set(ylim=(0, .33), xlim=(1989,2020))
#ax.set(ylim=(0, 1))
#ax.set(ylim=(-.5,.5))
plt.show()

# %%
# if good, export
ax.get_figure().savefig(file[:-4] + '.jpg', dpi=300, bbox_inches='tight')
