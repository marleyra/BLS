# %%
import numpy as np
import pandas as pd

# %%
# load csv of all US fips
fips = pd.read_csv('https://raw.githubusercontent.com/kjhealy/us-county/master/data/census/fips-by-state.csv',
                   encoding= 'unicode_escape')

# load csv of US regions
url = 'https://raw.githubusercontent.com/cphalpert/census-regions/master/us%20census%20bureau%20regions%20and%20divisions.csv'
r = pd.read_csv(url)

# %%
# assign each fips a region and division
rf = fips.merge(r, how='left', left_on='state', right_on='State Code')

# drop extra col
rf = rf.drop('state', axis=1)

# fix fips
rf['fips'] = rf['fips'].astype(str).str.zfill(5)
rf.sample(5)
# Out:
#        fips             name     State State Code   Region            Division
# 1259  26057   Gratiot County  Michigan         MI  Midwest  East North Central
# 2185  40109  Oklahoma County  Oklahoma         OK    South  West South Central
# 501   13233      Polk County   Georgia         GA    South      South Atlantic
# 2625  48205   Hartley County     Texas         TX    South  West South Central
# 2796  49039   Sanpete County      Utah         UT     West            Mountain

# %%
# load Metro/Micro delineations file

#omb03 = pd.read_csv('omb-cbsa-csa_2003.csv')
#bls13 = pd.read_csv('qcew-county-msa-csa-crosswalk.csv', encoding = 'ISO-8859-1') # BLS13 is the "master" sheet, with null values for non Metro/Micro counties
#cen20 = pd.read_csv('census_2020.csv')
#met20 = pd.read_csv('METROS_2020.csv')
#mic20 = pd.read_csv('MICROS_2020.csv')

bea20 = pd.read_csv('typology/BEA_2020.csv')

# %%
# create normal fips
bea20['fips'] = bea20['fips'].astype(str).str.zfill(5)

# process BEA delineations
bea20['type_bea20'] = bea20['msa'].str.split('(').str[1].str[:5]

# strip extraneous text from MSA name
bea20['msa'] = bea20['msa'].str.split('(').str[0]

# drop extra col
bea20 = bea20.drop('msa_code', axis=1)

# %%
# merge master fips/regions/divisions + Metro/Micro
df = rf.merge(bea20, how='outer', on='fips')
df = df.drop('county_name', axis=1)
df
# Out:
#        fips            name    State State Code Region            Division  \
# 0     01001  Autauga County  Alabama         AL  South  East South Central
# 1     01003  Baldwin County  Alabama         AL  South  East South Central
# 2     01005  Barbour County  Alabama         AL  South  East South Central
# 3     01007     Bibb County  Alabama         AL  South  East South Central
# 4     01009   Blount County  Alabama         AL  South  East South Central
# ...     ...             ...      ...        ...    ...                 ...
# 3159  51921             NaN      NaN        NaN    NaN                 NaN
# 3160  51955             NaN      NaN        NaN    NaN                 NaN
# 3161  51939             NaN      NaN        NaN    NaN                 NaN
# 3162  51929             NaN      NaN        NaN    NaN                 NaN
# 3163  55901             NaN      NaN        NaN    NaN                 NaN
#
#                              msa type_bea20
# 0                Montgomery, AL       Metro
# 1     Daphne-Fairhope-Foley, AL       Metro
# 2                Eufaula, AL-GA       Micro
# 3         Birmingham-Hoover, AL       Metro
# 4         Birmingham-Hoover, AL       Metro
# ...                          ...        ...
# 3159          Winchester, VA-WV       Metro
# 3160          Big Stone Gap, VA       Micro
# 3161               Danville, VA       Micro
# 3162           Martinsville, VA       Micro
# 3163                Shawano, WI       Micro
#
# [3164 rows x 8 columns]

# %%
# all unmatched counties are special BEA combo areas
df[df['fips'].notna() & df['name'].isna()]
# Out:
#        fips name State State Code Region Division  \
# 3143  51933  NaN   NaN        NaN    NaN      NaN
# 3144  51901  NaN   NaN        NaN    NaN      NaN
# 3145  51947  NaN   NaN        NaN    NaN      NaN
# 3146  15901  NaN   NaN        NaN    NaN      NaN
# 3147  51953  NaN   NaN        NaN    NaN      NaN
# 3148  51911  NaN   NaN        NaN    NaN      NaN
# 3149  51918  NaN   NaN        NaN    NaN      NaN
# 3150  51941  NaN   NaN        NaN    NaN      NaN
# 3151  51944  NaN   NaN        NaN    NaN      NaN
# 3152  51907  NaN   NaN        NaN    NaN      NaN
# 3153  51931  NaN   NaN        NaN    NaN      NaN
# 3154  51949  NaN   NaN        NaN    NaN      NaN
# 3155  51958  NaN   NaN        NaN    NaN      NaN
# 3156  51919  NaN   NaN        NaN    NaN      NaN
# 3157  51942  NaN   NaN        NaN    NaN      NaN
# 3158  51951  NaN   NaN        NaN    NaN      NaN
# 3159  51921  NaN   NaN        NaN    NaN      NaN
# 3160  51955  NaN   NaN        NaN    NaN      NaN
# 3161  51939  NaN   NaN        NaN    NaN      NaN
# 3162  51929  NaN   NaN        NaN    NaN      NaN
# 3163  55901  NaN   NaN        NaN    NaN      NaN
#
#                                                 msa type_bea20
# 3143                 Blacksburg-Christiansburg, VA       Metro
# 3144                           Charlottesville, VA       Metro
# 3145                              Harrisonburg, VA       Metro
# 3146                   Kahului-Wailuku-Lahaina, HI       Metro
# 3147                      Kingsport-Bristol, TN-VA       Metro
# 3148                                 Lynchburg, VA       Metro
# 3149                                  Richmond, VA       Metro
# 3150                                  Richmond, VA       Metro
# 3151                                   Roanoke, VA       Metro
# 3152                                  Staunton, VA       Metro
# 3153    Virginia Beach-Norfolk-Newport News, VA-NC       Metro
# 3154    Virginia Beach-Norfolk-Newport News, VA-NC       Metro
# 3155    Virginia Beach-Norfolk-Newport News, VA-NC       Metro
# 3156  Washington-Arlington-Alexandria, DC-VA-MD-WV       Metro
# 3157  Washington-Arlington-Alexandria, DC-VA-MD-WV       Metro
# 3158  Washington-Arlington-Alexandria, DC-VA-MD-WV       Metro
# 3159                             Winchester, VA-WV       Metro
# 3160                             Big Stone Gap, VA       Micro
# 3161                                  Danville, VA       Micro
# 3162                              Martinsville, VA       Micro
# 3163                                   Shawano, WI       Micro

# %%
# count which states are most affected
df[df['fips'].notna() & df['name'].isna()]['msa'].str[-3:].value_counts()
# Out:
# VA     12
# WV      4
# NC      3
# HI      1
# WI      1
# Name: msa, dtype: int64

# %%
# drop these in accordance w ECH methodlogy
df = df.drop(df[df['fips'].notna() & df['name'].isna()].index)
df.shape
# Out:
# (3143, 8)

# %% [markdown]
# #### Rurals
# According to HHS: _The Census does not actually define "rural." "Rural" encompasses all population, housing, and territory not included within an urban area.  Whatever is not urban is considered rural._
#
# Therefore, we change _null_ typologies to _Rural:_

# %%
df['type_bea20'] = df['type_bea20'].fillna('Rural')
df['type_bea20'].value_counts()
# Out:
# Rural    1345
# Metro    1143
# Micro     655
# Name: type_bea20, dtype: int64

# %%
# export df
df.to_csv('typology/region_delineation.csv', index_label=False)

# %% [markdown]
# ## OR

# %%
# add other regional classification
reg = pd.read_csv('typology/regions.csv')

# merge alternative region to df
data = df.merge(reg, how='left', left_on='State', right_on='STATE')

# assign DC an alt region
data.loc[data[data.State == 'District of Columbia'].index, 'REGION'] = 'Mid-Atlantic'

# clean cols
data = data.rename(columns={'REGION' : 'Region_alt'})
cols = data.columns[:6].tolist() + ['Region_alt'] + data.columns[6:8].tolist()

# export
data[cols].to_csv('typology/typology.csv', index_label=False)

# %%
data
# Out:
#        fips               name    State State Code Region            Division  \
# 0     01001     Autauga County  Alabama         AL  South  East South Central
# 1     01003     Baldwin County  Alabama         AL  South  East South Central
# 2     01005     Barbour County  Alabama         AL  South  East South Central
# 3     01007        Bibb County  Alabama         AL  South  East South Central
# 4     01009      Blount County  Alabama         AL  South  East South Central
# ...     ...                ...      ...        ...    ...                 ...
# 3138  56037  Sweetwater County  Wyoming         WY   West            Mountain
# 3139  56039       Teton County  Wyoming         WY   West            Mountain
# 3140  56041       Uinta County  Wyoming         WY   West            Mountain
# 3141  56043    Washakie County  Wyoming         WY   West            Mountain
# 3142  56045      Weston County  Wyoming         WY   West            Mountain
#
#                              msa type_bea20    STATE          Region_alt
# 0                Montgomery, AL       Metro  Alabama               South
# 1     Daphne-Fairhope-Foley, AL       Metro  Alabama               South
# 2                Eufaula, AL-GA       Micro  Alabama               South
# 3         Birmingham-Hoover, AL       Metro  Alabama               South
# 4         Birmingham-Hoover, AL       Metro  Alabama               South
# ...                          ...        ...      ...                 ...
# 3138           Rock Springs, WY       Micro  Wyoming  Interior Northwest
# 3139             Jackson, WY-ID       Micro  Wyoming  Interior Northwest
# 3140               Evanston, WY       Micro  Wyoming  Interior Northwest
# 3141                         NaN      Rural  Wyoming  Interior Northwest
# 3142               Gillette, WY       Micro  Wyoming  Interior Northwest
#
# [3143 rows x 10 columns]
